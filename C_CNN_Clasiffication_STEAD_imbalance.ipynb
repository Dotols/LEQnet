# %%
import pickle
import os
import numpy as np
import time

import torch
import torch.nn as nn
import torchvision.models as models
from torch.utils.data import DataLoader, Dataset

import numpy as np
import matplotlib.pyplot as plt

from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split

DEVICE = torch.device('cuda:1' if torch.cuda.is_available() else 'cpu')

def load_dataset(source, imbalance = True):
    DIR = os.getcwd()
    if source == 'STEAD':
        data_path = os.path.join(DIR, 'labeled_dump_STEAD')
    if source == 'PUSAN':
        data_path = os.path.join(DIR, 'labeled_dump')
        
    data_list = sorted(os.listdir(data_path))
    
    if imbalance == False:
        index = 1
    else:
        index = 0
        
    for idx, data in enumerate(data_list[index:index+1]):
        with open(os.path.join(data_path, data), 'rb') as f:
            if idx == 0:
                dataset = pickle.load(f)
            else:
                dataset = np.concatenate((dataset, pickle.load(f)))

    print('DEVICE \t\t: ', DEVICE)
    print('pid \t\t: ', os.getpid())

    print('\n---------------------------------Data---------------------------------\n')

    class SeismicDataset(Dataset): 
        def __init__(self, xs, ys):
            self.x_data = xs
            self.y_data = ys

        def __len__(self): 
            return len(self.x_data)

        def __getitem__(self, idx): 
            x = self.x_data[idx]
            y = self.y_data[idx]
            return x, y

    def make_x_p_s(dataset):

    #     x = np.array([(dataset[i]['data'].T - np.min(dataset[i]['data']))/(np.max(dataset[i]['data']) - np.min(dataset[i]['data'])) for i in range(len(dataset))])
        x = np.array([dataset[i]['data'].T for i in range(len(dataset))])
        y_p = np.array([dataset[i]['p_label'] for i in range(len(dataset))])[:,np.newaxis]
        y_s = np.array([dataset[i]['s_label'] for i in range(len(dataset))])[:,np.newaxis]
        
        t_count = [dataset[i]['p_label'] for i in range(len(dataset))].count(1)
        f_count = [dataset[i]['p_label'] for i in range(len(dataset))].count(0)
        
        print('data length \t: ', len(dataset))
        print('True count \t:', t_count)
        print('False count \t:', f_count)
        print('T/F ratio \t:', 100*t_count/(t_count+f_count), '%')
        print()


        return torch.as_tensor(x.astype(np.float32)), torch.as_tensor(y_p.astype(np.float32)), torch.as_tensor(y_s.astype(np.float32))

    def train_test_valid_split(dataset):
        train, test = train_test_split(dataset, 
                                       test_size=0.3, 
                                       shuffle=True, 
                                       random_state=1004)
        valid = test[int(0.25*len(test)):]
        test = test[:int(0.25*len(test))]

        return train, test, valid

    x, y_p, y_s = make_x_p_s(dataset)

    train_x, valid_x, test_x  = train_test_valid_split(x)
    train_y_p, valid_y_p, test_y_p  = train_test_valid_split(y_p)
    train_y_s, valid_y_s, test_y_s = train_test_valid_split(y_s)

    print('Train size \t:',  len(train_x))
    print('Valid size \t:', len(valid_x))
    print('Test size \t:', len(test_x))
    print()
    print('x shape \t:', x.shape)
    print('y_p shape \t:',y_p.shape)

    print('\n------------------------------Data Loader------------------------------\n')

    train_loader = DataLoader(
        dataset=SeismicDataset(train_x, train_y_p), batch_size=500, shuffle=True
    )
    valid_loader = DataLoader(
        dataset=SeismicDataset(test_x, test_y_p), batch_size=500, shuffle=True
    )
    test_loader = DataLoader(
        dataset=SeismicDataset(valid_x, valid_y_p), batch_size=500, shuffle=True
    )

    for (X_train, y_train) in train_loader : 
        print('X_train : ', X_train.size() , ' \ttype : ', X_train.type())
        print('y_train : ', y_train.size() , ' \t\ttype : ', y_train.type())
        break
        
    
    return len(train_x), train_loader, valid_loader, test_loader

train_length, train_loader, valid_loader, test_loader = load_dataset('STEAD', imbalance = True)
# Out:
# DEVICE 		:  cuda:1
# pid 		:  901
# data length 	:  10000
#
# ---------------------------------Data---------------------------------
#
# True count 	: 1000
# False count 	: 9000
# T/F ratio 	: 10.0 %
#
# Train size 	: 7000
# Valid size 	: 750
# Test size 	: 2250
#
# x shape 	: torch.Size([10000, 3, 6000])
# y_p shape 	: torch.Size([10000, 1])
#
# ------------------------------Data Loader------------------------------
#
# X_train :  torch.Size([500, 3, 6000])  	type :  torch.FloatTensor
# y_train :  torch.Size([500, 1])  		type :  torch.FloatTensor

# %%
class CNNEncoder(nn.Module):
    def __init__(self):
        super(CNNEncoder, self).__init__()
        kernel_size = 200
        self.conv1 = nn.Conv1d(3, 4, kernel_size=kernel_size, padding=kernel_size//2)
        self.maxpool1 = nn.MaxPool1d(kernel_size=2, stride=2)
        self.conv2 = nn.Conv1d(4, 8, kernel_size=(kernel_size-2), padding=(kernel_size-2)//2)
        self.maxpool2 = nn.MaxPool1d(kernel_size=2, stride=2)
        self.conv3 = nn.Conv1d(8, 16, kernel_size=(kernel_size-4), padding=(kernel_size-4)//2)
        self.maxpool3 = nn.MaxPool1d(kernel_size=2, stride=2)
        self.conv4 = nn.Conv1d(16, 32, kernel_size=(kernel_size-6), padding=(kernel_size-6)//2)
        self.maxpool4 = nn.MaxPool1d(kernel_size=2, stride=2)
        
        self.relu1 = nn.ReLU()
        self.dropout1 = nn.Dropout(p=0.5)
        self.relu2 = nn.ReLU()
        self.dropout2 = nn.Dropout(p=0.5)
        self.relu3 = nn.ReLU()
        self.dropout3 = nn.Dropout(p=0.5)
        self.relu4 = nn.ReLU()
        self.dropout4 = nn.Dropout(p=0.5)
        
        
        self.relu5 = nn.ReLU()
        self.relu6 = nn.ReLU()
        
        self.fc1 = nn.Linear(in_features=32 * 375, out_features=1500)
        self.fc2 = nn.Linear(in_features=1500, out_features= 100)
        self.fc3 = nn.Linear(in_features=100, out_features=1) 
        self.softmax = nn.Softmax()
        self.sigmoid = nn.Sigmoid()
        
    def forward(self, inp):
        inp = inp.to(DEVICE, dtype=torch.float)
        out = self.conv1(inp)
        out = self.relu1(out)
        out = self.dropout1(out)
        out = self.maxpool1(out)
        
        out = self.conv2(out)
        out = self.relu2(out)
        out = self.dropout2(out)
        out = self.maxpool2(out)
        
        out = self.conv3(out)
        out = self.relu3(out)
        out = self.dropout3(out)
        out = self.maxpool3(out)
        
        out = self.conv4(out)
        out = self.relu4(out)
        out = self.dropout4(out)
        out = self.maxpool4(out)
        
        out = out.view(-1, 32 * 375)
        
        out = self.fc1(out)
        out = self.relu5(out)
        out = self.fc2(out)
        out = self.relu6(out)
        out = self.fc3(out)
        
        out = self.sigmoid(out)
        
        return out
    
def metric(test_outputs, test_y_p):
    cnt = 0
    TP = FP = TN = FN = 0 + sys.float_info.epsilon
    for idx in range(len(test_y_p)):
        if int(torch.round(test_outputs[idx])) == 1 and int(torch.round(test_y_p[idx])) == 1:
            TP += 1
        if int(torch.round(test_outputs[idx])) == 1 and int(torch.round(test_y_p[idx])) == 0:
            FP += 1
        if int(torch.round(test_outputs[idx])) == 0 and int(torch.round(test_y_p[idx])) == 0:
            TN += 1
        if int(torch.round(test_outputs[idx])) == 0 and int(torch.round(test_y_p[idx])) == 1:
            FN += 1
            
    accuracy = (TP + TN) / (TP + FP + TN + FN)
    precision = TP / (TP + FP)
    recall = TP / (TP + FN)
    F1_score = 2*(precision * recall)/(precision + recall)
    
    return accuracy, precision, recall, F1_score

def save_fig(model_name, epoch, plot_dict):
    DIR = os.getcwd()
    output_dir = os.path.join(DIR, 'outputs', model_name)
    
    if not os.path.isdir(output_dir):
        os.mkdir(output_dir)
        
    plt.figure(figsize=(10, 5))
    plt.plot(plot_dict['losses'])
    plt.plot(plot_dict['val_losses'])
    plt.legend(['train', 'validation'], loc='upper right')
    plt.savefig(os.path.join(output_dir, model_name + '_' + str(epoch) + '_loss.png'))
    
    plt.figure(figsize=(10, 5))
    plt.plot(plot_dict['acc'])
    plt.plot(plot_dict['prec'])
    plt.plot(plot_dict['rec'])
    plt.plot(plot_dict['f1'])
    plt.legend(['val_accuracy', 'val_precision', 'val_recall', 'val_F1_score'], loc='lower right')
    plt.savefig(os.path.join(output_dir, model_name + '_' + str(epoch) + '_metric.png'))

# %%
num_epochs = 100
total_step = train_length//500

encoder = CNNEncoder().to(DEVICE)

criterion = nn.BCELoss(reduction='mean')
params = list(encoder.parameters())
optimizer = torch.optim.Adam(params, lr=0.0001)

plot_dict = dict()
losses = list()
val_losses = list()
acc = list()
prec = list()
rec = list()
f1 = list()

t0 = time.time()

for epoch in range(1, num_epochs+1):
    
    for i_step in range(1, total_step+1):
        encoder.train()
        encoder.zero_grad()
        
        inp, label = next(iter(train_loader))
        inp = inp.to(DEVICE)
        label = label.to(DEVICE)
        outputs = encoder(inp).to(DEVICE)
        loss = criterion(outputs, label)
        
        loss.backward()
        optimizer.step()
        
        # - - - Validate - - -
        with torch.no_grad():
            
            encoder.eval()

            val_inp, val_label = next(iter(valid_loader))
            val_inp = val_inp.to(DEVICE)
            val_label = val_label.to(DEVICE)
            val_outputs = encoder(val_inp).to(DEVICE)
            
            val_loss = criterion(val_outputs, val_label)
#             print('\n')
#             for i in range(10):
#                 print(torch.round(val_outputs[i]), val_label[i])
#                 print(torch.round(val_outputs[i]), torch.round(val_label[i]))
#                 print(int(val_outputs[i]), int(val_label[i]))
            val_accuracy, val_precision, val_recall, val_F1_score = metric(val_outputs, val_label)
#             break
        val_losses.append(val_loss.item())
        losses.append(loss.item())
        acc.append(val_accuracy)
        prec.append(val_precision)
        rec.append(val_recall)
        f1.append(val_F1_score)
        
        stats = 'Epoch [%d/%d], Step [%d/%d], Loss: %.4f, Val Loss: %.4f accuracy : %.4f, precision : %.4f, recall : %.4f, F1_score : %.4f' % \
                (epoch, num_epochs, i_step, total_step, loss.item(), val_loss.item(), val_accuracy, val_precision, val_recall, val_F1_score)
        
        print('\r', stats, end="")
        
#         f = sys.stdout
#         f = path
#         print(stats, 'Process in [%d/%d] step' % (i_step, total_step), file=f)
        
    print('\r', stats)
    
    plot_dict['val_losses'] = val_losses
    plot_dict['losses'] = losses
    plot_dict['acc'] = acc
    plot_dict['prec'] = prec
    plot_dict['rec'] = rec
    plot_dict['f1'] = f1
    
    if epoch == 1 or epoch == 3 or epoch == 5 or epoch%10 == 0:
        save_fig('balance', epoch, plot_dict)
    

t1 = time.time()

print('finished in {} seconds'.format(t1 - t0))
# Out:
#  Epoch [1/100], Step [14/14], Loss: 0.8992, Val Loss: 0.8653 accuracy : 0.7340, precision : 0.2515, recall : 0.8400, F1_score : 0.3871
#  Epoch [2/100], Step [14/14], Loss: 1.9480, Val Loss: 1.2078 accuracy : 0.9600, precision : 0.8085, recall : 0.7755, F1_score : 0.7917
#  Epoch [3/100], Step [14/14], Loss: 1.0878, Val Loss: 1.5395 accuracy : 0.9500, precision : 0.7800, recall : 0.7358, F1_score : 0.7573
#  Epoch [4/100], Step [14/14], Loss: 1.6497, Val Loss: 1.4632 accuracy : 0.9700, precision : 0.9429, recall : 0.7174, F1_score : 0.8148
#  Epoch [5/100], Step [14/14], Loss: 0.9061, Val Loss: 1.9909 accuracy : 0.9540, precision : 0.9000, recall : 0.6545, F1_score : 0.7579
#  Epoch [6/100], Step [14/14], Loss: 1.3104, Val Loss: 0.4462 accuracy : 0.9720, precision : 0.8367, recall : 0.8723, F1_score : 0.8542
#  Epoch [7/100], Step [14/14], Loss: 0.6307, Val Loss: 0.5294 accuracy : 0.9500, precision : 0.7000, recall : 0.9825, F1_score : 0.8175
#  Epoch [8/100], Step [14/14], Loss: 0.6178, Val Loss: 0.5137 accuracy : 0.9620, precision : 0.7681, recall : 0.9464, F1_score : 0.8480
#  Epoch [9/100], Step [14/14], Loss: 1.4234, Val Loss: 0.6459 accuracy : 0.9760, precision : 0.8511, recall : 0.8889, F1_score : 0.8696
#  Epoch [10/100], Step [14/14], Loss: 1.1281, Val Loss: 0.9269 accuracy : 0.9820, precision : 0.9464, recall : 0.8983, F1_score : 0.9217
#  Epoch [11/100], Step [14/14], Loss: 0.2482, Val Loss: 0.1807 accuracy : 0.9920, precision : 1.0000, recall : 0.8974, F1_score : 0.9459
#  Epoch [12/100], Step [14/14], Loss: 0.2911, Val Loss: 0.4483 accuracy : 0.9720, precision : 0.7903, recall : 0.9800, F1_score : 0.8750
#  Epoch [13/100], Step [14/14], Loss: 0.2963, Val Loss: 0.7149 accuracy : 0.9800, precision : 0.9038, recall : 0.9038, F1_score : 0.9038
#  Epoch [14/100], Step [14/14], Loss: 0.0697, Val Loss: 0.4258 accuracy : 0.9760, precision : 0.8500, recall : 0.9444, F1_score : 0.8947
#  Epoch [15/100], Step [14/14], Loss: 0.2787, Val Loss: 0.1322 accuracy : 0.9920, precision : 0.9231, recall : 0.9730, F1_score : 0.9474
#  Epoch [16/100], Step [14/14], Loss: 0.2199, Val Loss: 0.3136 accuracy : 0.9840, precision : 0.8409, recall : 0.9737, F1_score : 0.9024
#  Epoch [17/100], Step [14/14], Loss: 0.6875, Val Loss: 0.1923 accuracy : 0.9620, precision : 0.7595, recall : 1.0000, F1_score : 0.8633
#  Epoch [18/100], Step [14/14], Loss: 0.9448, Val Loss: 0.2823 accuracy : 0.9800, precision : 0.9184, recall : 0.8824, F1_score : 0.9000
#  Epoch [19/100], Step [14/14], Loss: 0.4029, Val Loss: 0.3004 accuracy : 0.9920, precision : 0.9574, recall : 0.9574, F1_score : 0.9574
#  Epoch [20/100], Step [14/14], Loss: 0.4759, Val Loss: 0.2300 accuracy : 0.9820, precision : 0.9149, recall : 0.8958, F1_score : 0.9053
#  Epoch [21/100], Step [14/14], Loss: 0.0383, Val Loss: 0.1754 accuracy : 0.9960, precision : 0.9583, recall : 1.0000, F1_score : 0.9787
#  Epoch [22/100], Step [14/14], Loss: 0.0198, Val Loss: 0.3223 accuracy : 0.9900, precision : 0.9583, recall : 0.9388, F1_score : 0.9485
#  Epoch [23/100], Step [14/14], Loss: 0.1689, Val Loss: 0.4532 accuracy : 0.9760, precision : 0.8913, recall : 0.8542, F1_score : 0.8723
#  Epoch [24/100], Step [14/14], Loss: 0.2358, Val Loss: 0.2026 accuracy : 0.9860, precision : 0.8966, recall : 0.9811, F1_score : 0.9369
#  Epoch [25/100], Step [14/14], Loss: 1.0205, Val Loss: 0.6441 accuracy : 0.9760, precision : 0.8936, recall : 0.8571, F1_score : 0.8750
#  Epoch [26/100], Step [14/14], Loss: 0.5968, Val Loss: 0.2781 accuracy : 0.9680, precision : 0.7887, recall : 0.9825, F1_score : 0.8750
#  Epoch [27/100], Step [14/14], Loss: 0.6690, Val Loss: 0.7872 accuracy : 0.9780, precision : 0.8889, recall : 0.9057, F1_score : 0.8972
#  Epoch [28/100], Step [14/14], Loss: 0.0812, Val Loss: 0.5231 accuracy : 0.9860, precision : 0.9531, recall : 0.9385, F1_score : 0.9457
#  Epoch [29/100], Step [14/14], Loss: 0.2552, Val Loss: 0.2047 accuracy : 0.9900, precision : 0.9048, recall : 0.9744, F1_score : 0.9383
#  Epoch [30/100], Step [14/14], Loss: 0.2359, Val Loss: 0.5656 accuracy : 0.9840, precision : 0.8868, recall : 0.9592, F1_score : 0.9216
#  Epoch [31/100], Step [14/14], Loss: 0.0169, Val Loss: 0.4122 accuracy : 0.9900, precision : 1.0000, recall : 0.8913, F1_score : 0.9425
#  Epoch [32/100], Step [14/14], Loss: 0.5170, Val Loss: 0.1480 accuracy : 0.9940, precision : 0.9556, recall : 0.9773, F1_score : 0.9663
#  Epoch [33/100], Step [14/14], Loss: 0.4059, Val Loss: 0.2324 accuracy : 0.9960, precision : 1.0000, recall : 0.9615, F1_score : 0.9804
#  Epoch [34/100], Step [14/14], Loss: 0.0101, Val Loss: 0.0697 accuracy : 0.9960, precision : 0.9792, recall : 0.9792, F1_score : 0.9792
#  Epoch [35/100], Step [14/14], Loss: 0.6517, Val Loss: 0.0998 accuracy : 0.9960, precision : 0.9592, recall : 1.0000, F1_score : 0.9792
#  Epoch [36/100], Step [14/14], Loss: 0.0228, Val Loss: 0.1091 accuracy : 0.9960, precision : 1.0000, recall : 0.9592, F1_score : 0.9792
#  Epoch [37/100], Step [14/14], Loss: 0.2607, Val Loss: 0.2490 accuracy : 0.9980, precision : 1.0000, recall : 0.9815, F1_score : 0.9907
#  Epoch [38/100], Step [14/14], Loss: 0.2030, Val Loss: 0.3495 accuracy : 0.9960, precision : 1.0000, recall : 0.9615, F1_score : 0.9804
#  Epoch [39/100], Step [14/14], Loss: 0.0691, Val Loss: 0.0666 accuracy : 0.9940, precision : 0.9388, recall : 1.0000, F1_score : 0.9684
#  Epoch [40/100], Step [14/14], Loss: 3.0100, Val Loss: 0.6772 accuracy : 0.8980, precision : 0.4796, recall : 1.0000, F1_score : 0.6483
#  Epoch [41/100], Step [14/14], Loss: 0.4879, Val Loss: 0.1731 accuracy : 0.9820, precision : 0.8667, recall : 0.9811, F1_score : 0.9204
#  Epoch [42/100], Step [14/14], Loss: 0.0340, Val Loss: 0.1299 accuracy : 0.9960, precision : 1.0000, recall : 0.9630, F1_score : 0.9811
#  Epoch [43/100], Step [14/14], Loss: 0.2190, Val Loss: 0.1585 accuracy : 0.9880, precision : 0.8182, recall : 1.0000, F1_score : 0.9000
#  Epoch [44/100], Step [14/14], Loss: 0.2425, Val Loss: 0.2293 accuracy : 0.9940, precision : 0.9623, recall : 0.9808, F1_score : 0.9714
#  Epoch [45/100], Step [14/14], Loss: 0.0385, Val Loss: 0.1556 accuracy : 0.9900, precision : 0.8980, recall : 1.0000, F1_score : 0.9462
#  Epoch [46/100], Step [14/14], Loss: 0.2256, Val Loss: 0.3045 accuracy : 0.9980, precision : 1.0000, recall : 0.9756, F1_score : 0.9877
#  Epoch [47/100], Step [14/14], Loss: 0.0109, Val Loss: 0.0851 accuracy : 1.0000, precision : 1.0000, recall : 1.0000, F1_score : 1.0000
#  Epoch [48/100], Step [14/14], Loss: 0.0121, Val Loss: 0.0806 accuracy : 1.0000, precision : 1.0000, recall : 1.0000, F1_score : 1.0000
#  Epoch [49/100], Step [14/14], Loss: 0.0105, Val Loss: 0.2674 accuracy : 0.9980, precision : 1.0000, recall : 0.9762, F1_score : 0.9880
#  Epoch [50/100], Step [14/14], Loss: 0.2034, Val Loss: 0.1383 accuracy : 0.9960, precision : 1.0000, recall : 0.9636, F1_score : 0.9815
#  Epoch [51/100], Step [14/14], Loss: 0.0518, Val Loss: 0.0949 accuracy : 0.9960, precision : 0.9545, recall : 1.0000, F1_score : 0.9767
#  Epoch [52/100], Step [14/14], Loss: 0.1564, Val Loss: 0.3085 accuracy : 0.9320, precision : 0.6136, recall : 1.0000, F1_score : 0.7606
#  Epoch [53/100], Step [14/14], Loss: 0.7819, Val Loss: 0.4730 accuracy : 0.9840, precision : 0.9592, recall : 0.8868, F1_score : 0.9216
#  Epoch [54/100], Step [14/14], Loss: 0.6091, Val Loss: 0.3572 accuracy : 0.9900, precision : 0.9412, recall : 0.9600, F1_score : 0.9505
#  Epoch [55/100], Step [14/14], Loss: 0.0142, Val Loss: 0.1097 accuracy : 0.9880, precision : 0.9000, recall : 1.0000, F1_score : 0.9474
#  Epoch [56/100], Step [14/14], Loss: 0.3690, Val Loss: 0.2572 accuracy : 0.9860, precision : 0.8824, recall : 0.9783, F1_score : 0.9278
#  Epoch [57/100], Step [14/14], Loss: 0.1661, Val Loss: 0.0924 accuracy : 0.9980, precision : 1.0000, recall : 0.9787, F1_score : 0.9892
#  Epoch [58/100], Step [14/14], Loss: 0.6788, Val Loss: 0.3196 accuracy : 0.9780, precision : 0.8246, recall : 0.9792, F1_score : 0.8952
#  Epoch [59/100], Step [14/14], Loss: 1.0663, Val Loss: 0.2968 accuracy : 0.9140, precision : 0.5326, recall : 1.0000, F1_score : 0.6950
#  Epoch [60/100], Step [14/14], Loss: 0.5004, Val Loss: 0.2002 accuracy : 0.9900, precision : 0.9808, recall : 0.9273, F1_score : 0.9533
#  Epoch [61/100], Step [14/14], Loss: 0.0069, Val Loss: 0.1863 accuracy : 0.9980, precision : 1.0000, recall : 0.9815, F1_score : 0.9907
#  Epoch [62/100], Step [14/14], Loss: 0.0102, Val Loss: 0.1605 accuracy : 1.0000, precision : 1.0000, recall : 1.0000, F1_score : 1.0000
#  Epoch [63/100], Step [14/14], Loss: 0.2262, Val Loss: 0.1727 accuracy : 0.9960, precision : 0.9661, recall : 1.0000, F1_score : 0.9828
#  Epoch [64/100], Step [14/14], Loss: 0.2109, Val Loss: 0.1276 accuracy : 0.9980, precision : 0.9792, recall : 1.0000, F1_score : 0.9895
#  Epoch [65/100], Step [14/14], Loss: 0.2154, Val Loss: 0.1029 accuracy : 0.9980, precision : 0.9808, recall : 1.0000, F1_score : 0.9903
#  Epoch [66/100], Step [14/14], Loss: 0.0033, Val Loss: 0.0781 accuracy : 1.0000, precision : 1.0000, recall : 1.0000, F1_score : 1.0000
#  Epoch [67/100], Step [14/14], Loss: 0.2225, Val Loss: 0.0689 accuracy : 1.0000, precision : 1.0000, recall : 1.0000, F1_score : 1.0000
#  Epoch [68/100], Step [14/14], Loss: 0.2013, Val Loss: 0.0945 accuracy : 0.9960, precision : 0.9800, recall : 0.9800, F1_score : 0.9800
#  Epoch [69/100], Step [14/14], Loss: 0.2009, Val Loss: 0.0854 accuracy : 0.9980, precision : 0.9841, recall : 1.0000, F1_score : 0.9920
#  Epoch [70/100], Step [14/14], Loss: 0.4006, Val Loss: 0.0731 accuracy : 0.9960, precision : 0.9804, recall : 0.9804, F1_score : 0.9804
#  Epoch [71/100], Step [14/14], Loss: 0.4017, Val Loss: 0.0710 accuracy : 0.9980, precision : 1.0000, recall : 0.9773, F1_score : 0.9885
#  Epoch [72/100], Step [14/14], Loss: 0.0008, Val Loss: 0.0765 accuracy : 0.9960, precision : 1.0000, recall : 0.9667, F1_score : 0.9831
#  Epoch [73/100], Step [14/14], Loss: 0.2042, Val Loss: 0.0635 accuracy : 0.9980, precision : 0.9841, recall : 1.0000, F1_score : 0.9920
#  Epoch [74/100], Step [14/14], Loss: 0.2011, Val Loss: 0.0649 accuracy : 0.9960, precision : 0.9804, recall : 0.9804, F1_score : 0.9804
#  Epoch [75/100], Step [14/14], Loss: 0.0008, Val Loss: 0.0589 accuracy : 1.0000, precision : 1.0000, recall : 1.0000, F1_score : 1.0000
#  Epoch [76/100], Step [14/14], Loss: 0.2137, Val Loss: 0.0629 accuracy : 1.0000, precision : 1.0000, recall : 1.0000, F1_score : 1.0000
#  Epoch [77/100], Step [14/14], Loss: 0.2021, Val Loss: 0.0672 accuracy : 0.9960, precision : 1.0000, recall : 0.9615, F1_score : 0.9804
#  Epoch [78/100], Step [14/14], Loss: 0.2057, Val Loss: 0.0585 accuracy : 1.0000, precision : 1.0000, recall : 1.0000, F1_score : 1.0000
#  Epoch [79/100], Step [14/14], Loss: 0.2050, Val Loss: 0.0734 accuracy : 0.9980, precision : 0.9815, recall : 1.0000, F1_score : 0.9907
#  Epoch [80/100], Step [14/14], Loss: 0.0007, Val Loss: 0.0606 accuracy : 0.9980, precision : 0.9808, recall : 1.0000, F1_score : 0.9903
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:98: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:104: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#  Epoch [81/100], Step [14/14], Loss: 0.4005, Val Loss: 0.0501 accuracy : 1.0000, precision : 1.0000, recall : 1.0000, F1_score : 1.0000
#  Epoch [82/100], Step [14/14], Loss: 0.0004, Val Loss: 0.0532 accuracy : 1.0000, precision : 1.0000, recall : 1.0000, F1_score : 1.0000
#  Epoch [83/100], Step [14/14], Loss: 0.2017, Val Loss: 0.0665 accuracy : 0.9980, precision : 0.9787, recall : 1.0000, F1_score : 0.9892
#  Epoch [84/100], Step [14/14], Loss: 0.4006, Val Loss: 0.0610 accuracy : 0.9980, precision : 0.9839, recall : 1.0000, F1_score : 0.9919
#  Epoch [85/100], Step [14/14], Loss: 0.0046, Val Loss: 0.0474 accuracy : 1.0000, precision : 1.0000, recall : 1.0000, F1_score : 1.0000
#  Epoch [86/100], Step [14/14], Loss: 0.2003, Val Loss: 0.0849 accuracy : 0.9960, precision : 0.9787, recall : 0.9787, F1_score : 0.9787
#  Epoch [87/100], Step [14/14], Loss: 0.0003, Val Loss: 0.0689 accuracy : 0.9980, precision : 0.9815, recall : 1.0000, F1_score : 0.9907
#  Epoch [88/100], Step [14/14], Loss: 0.0002, Val Loss: 0.0592 accuracy : 0.9980, precision : 0.9815, recall : 1.0000, F1_score : 0.9907
#  Epoch [89/100], Step [14/14], Loss: 0.2005, Val Loss: 0.0386 accuracy : 0.9980, precision : 1.0000, recall : 0.9796, F1_score : 0.9897
#  Epoch [90/100], Step [14/14], Loss: 0.0005, Val Loss: 0.2372 accuracy : 0.9980, precision : 1.0000, recall : 0.9818, F1_score : 0.9908
#  Epoch [91/100], Step [14/14], Loss: 0.2001, Val Loss: 0.0568 accuracy : 0.9980, precision : 0.9833, recall : 1.0000, F1_score : 0.9916
#  Epoch [92/100], Step [14/14], Loss: 0.2007, Val Loss: 0.0454 accuracy : 0.9980, precision : 1.0000, recall : 0.9762, F1_score : 0.9880
#  Epoch [93/100], Step [14/14], Loss: 0.0086, Val Loss: 0.0747 accuracy : 0.9960, precision : 0.9583, recall : 1.0000, F1_score : 0.9787
#  Epoch [94/100], Step [14/14], Loss: 0.0020, Val Loss: 0.0340 accuracy : 1.0000, precision : 1.0000, recall : 1.0000, F1_score : 1.0000
#  Epoch [95/100], Step [14/14], Loss: 0.2016, Val Loss: 0.0441 accuracy : 0.9980, precision : 1.0000, recall : 0.9815, F1_score : 0.9907
#  Epoch [96/100], Step [14/14], Loss: 0.2065, Val Loss: 0.0403 accuracy : 1.0000, precision : 1.0000, recall : 1.0000, F1_score : 1.0000
#  Epoch [97/100], Step [14/14], Loss: 0.2048, Val Loss: 0.0458 accuracy : 0.9980, precision : 1.0000, recall : 0.9787, F1_score : 0.9892
#  Epoch [98/100], Step [14/14], Loss: 0.2147, Val Loss: 0.0438 accuracy : 0.9980, precision : 0.9811, recall : 1.0000, F1_score : 0.9905
#  Epoch [99/100], Step [14/14], Loss: 0.4004, Val Loss: 0.0367 accuracy : 1.0000, precision : 1.0000, recall : 1.0000, F1_score : 1.0000
#  Epoch [100/100], Step [14/14], Loss: 0.2003, Val Loss: 0.0396 accuracy : 0.9980, precision : 1.0000, recall : 0.9800, F1_score : 0.9899
# finished in 884.8441865444183 seconds

# %%
with torch.no_grad():
            
    encoder.eval()

    test_inp, test_label = next(iter(test_loader))
    test_inp = test_inp.to(DEVICE)
    test_label = test_label.to(DEVICE)
    test_outputs = encoder(test_inp).to(DEVICE)

    test_loss = criterion(test_outputs, test_label)
    test_accuracy, test_precision, test_recall, test_F1_score = metric(test_outputs, test_label)
        
stats = 'Loss: %.4f, accuracy : %.4f, precision : %.4f, recall : %.4f, F1_score : %.4f' % \
                (test_loss.item(), test_accuracy, test_precision, test_recall, test_F1_score)
        
print(stats)
# Out:
# Loss: 0.0571, accuracy : 0.9960, precision : 0.9844, recall : 0.9844, F1_score : 0.9844

# %% [markdown]
# # Recall (TP : Blue, FN : Red)

# %%
t_data = np.array([idx for idx, label in enumerate(test_label) if int(label) == 1])
plt.figure(figsize=(20, 20))
for i in tqdm(range(24)):
    plt.subplot(8, 3, i+1)
    plt.plot(test_inp[t_data[i]][0].to('cpu'), color='blue' if int(torch.round(test_outputs[t_data[i]])) == 1 else 'red')

plt.tight_layout()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=24.0), HTML(value='')))

# %%
f_data = np.array([idx for idx, label in enumerate(test_label) if int(label) == 0])
plt.figure(figsize=(20, 20))
for i in tqdm(range(24)):
    plt.subplot(8, 3, i+1)
    plt.plot(test_inp[f_data[i]][0].to('cpu'), color='red' if int(torch.round(test_outputs[f_data[i]])) == 0 else 'blue')

plt.tight_layout()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=24.0), HTML(value='')))

# %% [markdown]
# # Precision (TP : Blue, FP : Red)

# %%
p_data = np.array([idx for idx, output in enumerate(test_outputs) if int(torch.round(output)) == 1])
plt.figure(figsize=(20, 20))
for i in tqdm(range(24)):
    plt.subplot(8, 3, i+1)
    plt.plot(test_inp[p_data[i]][0].to('cpu'), color='blue' if int(torch.round(test_label[p_data[i]])) == 1 else 'red')

plt.tight_layout()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=24.0), HTML(value='')))

# %%
n_data = np.array([idx for idx, output in enumerate(test_outputs) if int(torch.round(output)) == 0])
plt.figure(figsize=(20, 20))
for i in tqdm(range(24)):
    plt.subplot(8, 3, i+1)
    plt.plot(test_inp[n_data[i]][0].to('cpu'), color='red' if int(torch.round(test_label[n_data[i]])) == 0 else 'blue')

plt.tight_layout()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=24.0), HTML(value='')))

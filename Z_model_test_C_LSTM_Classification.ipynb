# %%
# outps = np.zeros((500, 6000))
# labels = np.zeros((500, 6000))

# for jdx in range(500):
#     for idx in range(params['window_count']):
#         start = idx*dataset['window_size']
#         end = (idx+1)*dataset['window_size']
        
#         outps[jdx, start:end] = torch.round(test_outps[jdx, 0, idx])*torch.max(test_inps[jdx, 0])*0.8
#         labels[jdx, start:end] = test_labels[jdx, 0, idx]*torch.max(test_inps[jdx, 0])

# for idx in range(30):
#     plt.figure(figsize=(20,3))
#     plt.plot(labels[idx], color='orange' if 1 in test_labels[idx, 0] else 'green')
#     plt.plot(test_inps[idx, 0], color='black')
#     plt.plot(outps[idx], color='red' if 1 in test_labels[idx, 0] else 'blue')
#     plt.show()

# %%
from _preprocessing import *

params = dict()

# ------------------ configuration ------------------

params['source']                 = 'STEAD'
params['mode']                   = 'generator'
params['window_count']           = 6
params['condition']              = 'M>3'
params['imbalance']              = False
params['config_name']            = make_config(params)
params['file_name']              = params['source'] + '_' + params['config_name'] + '_dump.pkl'
params['model_name']             = 'LSTM_' + params['config_name']
params['output']                 = 'lstm'

# ------------------ preprocessing ------------------

params['output_name']            = 'test_trainer'
params['input_dimention']        = (6000, 3)
params['shuffle']                = True
params['label_type']             = 'gaussian'
params['normalization_mode']     = 'std'
params['augmentation']           = True
params['add_event_r']            = 0.6
params['add_gap_r']              = 0.2
params['add_noise_r']            = 0.5
params['drop_channel_r']         = 0.5
params['shift_event_r']          = 0.9
params['scale_amplitude_r']      = None
params['pre_emphasis']           = False

params['batch_size']             = 36
params['total_data_size']        = 20000
params['T/F_ratio']              = [0.5, 0.5]
params['train_valid_test_split'] = [0.60, 0.20, 0.20]

# ----------------- model-parameter -----------------

params['kernel_size']     = 20
params['embed_size']      = 512
params['hidden_size']     = 512

# ----------------- train-parameter -----------------

params['epochs']                 = 10
params['lr']                     = 0.001

import pprint
pprint.pprint(params)

preprocessing_generator(params)
# Out:
# Using TensorFlow backend.
# {'T/F_ratio': [0.5, 0.5],
#  'add_event_r': 0.6,
#  'add_gap_r': 0.2,
#  'add_noise_r': 0.5,
#  'augmentation': True,
#  'batch_size': 36,
#  'condition': 'M>3',
#  'config_name': 'W6_M>3_balance',
#  'drop_channel_r': 0.5,
#  'embed_size': 512,
#  'epochs': 10,
#  'file_name': 'STEAD_W6_M>3_balance_dump.pkl',
#  'hidden_size': 512,
#  'imbalance': False,
#  'input_dimention': (6000, 3),
#  'kernel_size': 20,
#  'label_type': 'gaussian',
#  'lr': 0.001,
#  'mode': 'generator',
#  'model_name': 'LSTM_W6_M>3_balance',
#  'normalization_mode': 'std',
#  'output': 'lstm',
#  'output_name': 'test_trainer',
#  'pre_emphasis': False,
#  'scale_amplitude_r': None,
#  'shift_event_r': 0.9,
#  'shuffle': True,
#  'source': 'STEAD',
#  'total_data_size': 20000,
#  'train_valid_test_split': [0.6, 0.2, 0.2],
#  'window_count': 6}
# file exist!!!

# %%
from _utils import *

dataset = load_dataset(params)
# Out:
# DEVICE 		:  cuda:1
# pid 		:  3254
#
# ---------------------------------Data---------------------------------
#
# file name 	: STEAD_W6_M>3_balance_dump.pkl
# data length 	: 20000
# T/F count 	: 10000 / 10000
# T/F ratio 	: 50.0 %
# Train size 	: 12000
# Valid size 	: 4000
# Test size 	: 4000
#
# ------------------------------Data Loader------------------------------
#
# X_train shape:  torch.Size([500, 3, 6000])  	type :  torch.FloatTensor
# y_train shape:  torch.Size([500, 1, 6])  	type :  torch.FloatTensor

# %%
from _C_LSTM_Classification import *

model = train(dataset, params)
# Out:
#  Epoch [1/10], Step [24/24], Loss: 0.1106, Val Loss: 0.1384, accuracy : 0.7580, precision : 0.9923, recall : 0.5181, F1_score : 0.6807, TP : 129, FP : 1, TN : 250, FN : 120
#  Epoch [2/10], Step [24/24], Loss: 0.0820, Val Loss: 0.0634, accuracy : 0.8820, precision : 0.9665, recall : 0.7953, F1_score : 0.8726, TP : 202, FP : 7, TN : 239, FN : 523
#  Epoch [3/10], Step [24/24], Loss: 0.0480, Val Loss: 0.0671, accuracy : 0.9020, precision : 0.9539, recall : 0.8415, F1_score : 0.8942, TP : 207, FP : 10, TN : 244, FN : 39
#  Epoch [4/10], Step [24/24], Loss: 0.0447, Val Loss: 0.0633, accuracy : 0.8980, precision : 0.9683, recall : 0.8295, F1_score : 0.8935, TP : 214, FP : 7, TN : 235, FN : 444
#  Epoch [5/10], Step [24/24], Loss: 0.0434, Val Loss: 0.0509, accuracy : 0.9160, precision : 0.9500, recall : 0.8837, F1_score : 0.9157, TP : 228, FP : 12, TN : 230, FN : 30
#  Epoch [6/10], Step [24/24], Loss: 0.0316, Val Loss: 0.0450, accuracy : 0.9280, precision : 0.9550, recall : 0.8908, F1_score : 0.9217, TP : 212, FP : 10, TN : 252, FN : 26
#  Epoch [7/10], Step [24/24], Loss: 0.0292, Val Loss: 0.0341, accuracy : 0.9480, precision : 0.9863, recall : 0.9038, F1_score : 0.9432, TP : 216, FP : 3, TN : 258, FN : 234
#  Epoch [8/10], Step [24/24], Loss: 0.0245, Val Loss: 0.0432, accuracy : 0.9140, precision : 0.9854, recall : 0.8354, F1_score : 0.9042, TP : 203, FP : 3, TN : 254, FN : 409
#  Epoch [9/10], Step [24/24], Loss: 0.0227, Val Loss: 0.0396, accuracy : 0.9260, precision : 0.9602, recall : 0.8857, F1_score : 0.9214, TP : 217, FP : 9, TN : 246, FN : 285
#  Epoch [10/10], Step [24/24], Loss: 0.0246, Val Loss: 0.0385, accuracy : 0.9400, precision : 0.9863, recall : 0.8889, F1_score : 0.9351, TP : 216, FP : 3, TN : 254, FN : 277
# finished in 92.28224658966064 seconds

# %%
test(model, dataset)
# Out:
# Loss: 0.0325, accuracy : 0.9520, precision : 0.9952, recall : 0.9009, F1_score : 0.9457
# TP : 209, FP : 1, TN : 267, FN : 23

# %%
import torchsummary

torchsummary.summary(model, (3, 6000), device='cuda')
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv1d-1              [-1, 4, 1001]             244
#               ReLU-2              [-1, 4, 1001]               0
#            Dropout-3              [-1, 4, 1001]               0
#          MaxPool1d-4               [-1, 4, 500]               0
#             Conv1d-5               [-1, 8, 501]             584
#               ReLU-6               [-1, 8, 501]               0
#            Dropout-7               [-1, 8, 501]               0
#          MaxPool1d-8               [-1, 8, 250]               0
#             Conv1d-9              [-1, 16, 251]           2,064
#              ReLU-10              [-1, 16, 251]               0
#           Dropout-11              [-1, 16, 251]               0
#         MaxPool1d-12              [-1, 16, 125]               0
#            Conv1d-13              [-1, 32, 126]           7,200
#              ReLU-14              [-1, 32, 126]               0
#           Dropout-15              [-1, 32, 126]               0
#         MaxPool1d-16               [-1, 32, 63]               0
#            Linear-17                  [-1, 512]       1,032,704
#        CNNEncoder-18                  [-1, 512]               0
#            Conv1d-19              [-1, 4, 1001]             244
#              ReLU-20              [-1, 4, 1001]               0
#           Dropout-21              [-1, 4, 1001]               0
#         MaxPool1d-22               [-1, 4, 500]               0
#            Conv1d-23               [-1, 8, 501]             584
#              ReLU-24               [-1, 8, 501]               0
#           Dropout-25               [-1, 8, 501]               0
#         MaxPool1d-26               [-1, 8, 250]               0
#            Conv1d-27              [-1, 16, 251]           2,064
#              ReLU-28              [-1, 16, 251]               0
#           Dropout-29              [-1, 16, 251]               0
#         MaxPool1d-30              [-1, 16, 125]               0
#            Conv1d-31              [-1, 32, 126]           7,200
#              ReLU-32              [-1, 32, 126]               0
#           Dropout-33              [-1, 32, 126]               0
#         MaxPool1d-34               [-1, 32, 63]               0
#            Linear-35                  [-1, 512]       1,032,704
#        CNNEncoder-36                  [-1, 512]               0
#            Conv1d-37              [-1, 4, 1001]             244
#              ReLU-38              [-1, 4, 1001]               0
#           Dropout-39              [-1, 4, 1001]               0
#         MaxPool1d-40               [-1, 4, 500]               0
#            Conv1d-41               [-1, 8, 501]             584
#              ReLU-42               [-1, 8, 501]               0
#           Dropout-43               [-1, 8, 501]               0
#         MaxPool1d-44               [-1, 8, 250]               0
#            Conv1d-45              [-1, 16, 251]           2,064
#              ReLU-46              [-1, 16, 251]               0
#           Dropout-47              [-1, 16, 251]               0
#         MaxPool1d-48              [-1, 16, 125]               0
#            Conv1d-49              [-1, 32, 126]           7,200
#              ReLU-50              [-1, 32, 126]               0
#           Dropout-51              [-1, 32, 126]               0
#         MaxPool1d-52               [-1, 32, 63]               0
#            Linear-53                  [-1, 512]       1,032,704
#        CNNEncoder-54                  [-1, 512]               0
#            Conv1d-55              [-1, 4, 1001]             244
#              ReLU-56              [-1, 4, 1001]               0
#           Dropout-57              [-1, 4, 1001]               0
#         MaxPool1d-58               [-1, 4, 500]               0
#            Conv1d-59               [-1, 8, 501]             584
#              ReLU-60               [-1, 8, 501]               0
#           Dropout-61               [-1, 8, 501]               0
#         MaxPool1d-62               [-1, 8, 250]               0
#            Conv1d-63              [-1, 16, 251]           2,064
#              ReLU-64              [-1, 16, 251]               0
#           Dropout-65              [-1, 16, 251]               0
#         MaxPool1d-66              [-1, 16, 125]               0
#            Conv1d-67              [-1, 32, 126]           7,200
#              ReLU-68              [-1, 32, 126]               0
#           Dropout-69              [-1, 32, 126]               0
#         MaxPool1d-70               [-1, 32, 63]               0
#            Linear-71                  [-1, 512]       1,032,704
#        CNNEncoder-72                  [-1, 512]               0
#            Conv1d-73              [-1, 4, 1001]             244
#              ReLU-74              [-1, 4, 1001]               0
#           Dropout-75              [-1, 4, 1001]               0
#         MaxPool1d-76               [-1, 4, 500]               0
#            Conv1d-77               [-1, 8, 501]             584
#              ReLU-78               [-1, 8, 501]               0
#           Dropout-79               [-1, 8, 501]               0
#         MaxPool1d-80               [-1, 8, 250]               0
#            Conv1d-81              [-1, 16, 251]           2,064
#              ReLU-82              [-1, 16, 251]               0
#           Dropout-83              [-1, 16, 251]               0
#         MaxPool1d-84              [-1, 16, 125]               0
#            Conv1d-85              [-1, 32, 126]           7,200
#              ReLU-86              [-1, 32, 126]               0
#           Dropout-87              [-1, 32, 126]               0
#         MaxPool1d-88               [-1, 32, 63]               0
#            Linear-89                  [-1, 512]       1,032,704
#        CNNEncoder-90                  [-1, 512]               0
#            Conv1d-91              [-1, 4, 1001]             244
#              ReLU-92              [-1, 4, 1001]               0
#           Dropout-93              [-1, 4, 1001]               0
#         MaxPool1d-94               [-1, 4, 500]               0
#            Conv1d-95               [-1, 8, 501]             584
#              ReLU-96               [-1, 8, 501]               0
#           Dropout-97               [-1, 8, 501]               0
#         MaxPool1d-98               [-1, 8, 250]               0
#            Conv1d-99              [-1, 16, 251]           2,064
#             ReLU-100              [-1, 16, 251]               0
#          Dropout-101              [-1, 16, 251]               0
#        MaxPool1d-102              [-1, 16, 125]               0
#           Conv1d-103              [-1, 32, 126]           7,200
#             ReLU-104              [-1, 32, 126]               0
#          Dropout-105              [-1, 32, 126]               0
#        MaxPool1d-106               [-1, 32, 63]               0
#           Linear-107                  [-1, 512]       1,032,704
#       CNNEncoder-108                  [-1, 512]               0
#         LSTMCell-109     [[-1, 512], [-1, 512]]               0
#           Linear-110                    [-1, 1]             513
#          Sigmoid-111                    [-1, 1]               0
#         LSTMCell-112     [[-1, 512], [-1, 512]]               0
#           Linear-113                    [-1, 1]             513
#          Sigmoid-114                    [-1, 1]               0
#         LSTMCell-115     [[-1, 512], [-1, 512]]               0
#           Linear-116                    [-1, 1]             513
#          Sigmoid-117                    [-1, 1]               0
#         LSTMCell-118     [[-1, 512], [-1, 512]]               0
#           Linear-119                    [-1, 1]             513
#          Sigmoid-120                    [-1, 1]               0
#         LSTMCell-121     [[-1, 512], [-1, 512]]               0
#           Linear-122                    [-1, 1]             513
#          Sigmoid-123                    [-1, 1]               0
#         LSTMCell-124     [[-1, 512], [-1, 512]]               0
#           Linear-125                    [-1, 1]             513
#          Sigmoid-126                    [-1, 1]               0
#       RNNDecoder-127                    [-1, 6]               0
# ================================================================
# Total params: 6,259,854
# Trainable params: 6,259,854
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.07
# Forward/backward pass size (MB): 9.38
# Params size (MB): 23.88
# Estimated Total Size (MB): 33.33
# ----------------------------------------------------------------

# %% [markdown]
# ######
